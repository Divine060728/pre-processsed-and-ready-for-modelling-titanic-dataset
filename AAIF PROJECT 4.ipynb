# %%
# importing libraries
import pandas as pd 
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
#loadign dataset
df_iris= pd.read_csv(r'C:\Users\Divine Martins\Downloads\archive\tested.csv')

# %%
#Finding basic info in the dataset
df.info()
df.describe()
df_iris.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Sex          418 non-null    object
#  4   Age          418 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Fare         418 non-null    float64
#  8   Embarked     418 non-null    object
#  9   Fare_log     418 non-null    float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 32.8+ KB
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#Filling null values
df_iris['Age']=df_iris['Age'].fillna(df_iris['Age'].median())

# %%
#checking to see if theyve beeen filled
df_iris.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#filling null values again
df_iris['Fare']=df_iris['Fare'].fillna(df_iris['Fare'].mean())

# %%
df_iris.drop(columns='Cabin', inplace=True)

# %%
# checking to see if they have been filled 
df_iris.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Fare_log       0
# FamilySize     0
# dtype: int64

# %%
#printing to see if the change has been effected
df_iris
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       2
# 1            893         1       2
# 2            894         0       1
# 3            895         0       2
# 4            896         1       2
# ..           ...       ...     ...
# 413         1305         0       2
# 414         1306         1       0
# 415         1307         0       2
# 416         1308         0       2
# 417         1309         0       2
#
#                                              Name  Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    1  0.452723      0
# 1                Wilkes, Mrs. James (Ellen Needs)    0  0.617566      1
# 2                       Myles, Mr. Thomas Francis    1  0.815377      0
# 3                                Wirz, Mr. Albert    1  0.353818      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0  0.287881      1
# ..                                            ...  ...       ...    ...
# ...

# %%
# to identify the outliers 

Q1 = df_iris['Fare'].quantile(0.25)
Q3 = df_iris['Fare'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR



outliers = df_iris[(df_iris['Fare'] < lower_bound) | (df_iris['Fare'] > upper_bound)]
print(outliers)
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       0
# 24           916         1       0
# 48           940         1       0
# 53           945         1       0
# 59           951         1       0
# 64           956         0       0
# 69           961         1       0
# 74           966         1       0
# 75           967         0       0
# 81           973         0       0
# 96           988         1       0
# 114         1006         1       0
# 118         1010         0       0
# 141         1033         1       0
# 142         1034         0       0
# 150         1042         1       0
# 156         1048         1       0
# 179         1071         1       0
# 181         1073         0       0
# 184         1076         1       0
# 188         1080         1       2
# 196         1088         0       0
# 202         1094         0       0
# 212         1104         0       1
# 217         1109         0       0
# ...

# %%
# handle the outliers
df_iris['Fare_log'] = np.log1p(df_iris['Fare'])

# %%
#Dropping useless columns 
df = df_iris.drop(columns=['Name', 'Ticket'])

# %%
#Encoding categorical data
le = LabelEncoder()
df_iris['Sex'] = le.fit_transform(df_iris['Sex'])
df_iris['Embarked'] = le.fit_transform(df_iris['Embarked'])
df_iris['Pclass'] = le.fit_transform(df_iris['Pclass'])

# %%
#scaling the fare and Age columns to be on the same number scale
scaler = MinMaxScaler()
df_iris[['Age', 'Fare']] = scaler.fit_transform(df_iris[['Age', 'Fare']])

# %%
# feature engineering is the creation of new columns using existing ones 
df_iris['FamilySize'] = df_iris['SibSp'] + df_iris['Parch'] + 1

# %%
# to see the final loook of the dataset
df_iris
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       2
# 1            893         1       2
# 2            894         0       1
# 3            895         0       2
# 4            896         1       2
# ..           ...       ...     ...
# 413         1305         0       2
# 414         1306         1       0
# 415         1307         0       2
# 416         1308         0       2
# 417         1309         0       2
#
#                                              Name  Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    1  0.452723      0
# 1                Wilkes, Mrs. James (Ellen Needs)    0  0.617566      1
# 2                       Myles, Mr. Thomas Francis    1  0.815377      0
# 3                                Wirz, Mr. Albert    1  0.353818      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0  0.287881      1
# ..                                            ...  ...       ...    ...
# ...

# %%
df_iris
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       2
# 1            893         1       2
# 2            894         0       1
# 3            895         0       2
# 4            896         1       2
# ..           ...       ...     ...
# 413         1305         0       2
# 414         1306         1       0
# 415         1307         0       2
# 416         1308         0       2
# 417         1309         0       2
#
#                                              Name  Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    1  0.452723      0
# 1                Wilkes, Mrs. James (Ellen Needs)    0  0.617566      1
# 2                       Myles, Mr. Thomas Francis    1  0.815377      0
# 3                                Wirz, Mr. Albert    1  0.353818      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0  0.287881      1
# ..                                            ...  ...       ...    ...
# ...
